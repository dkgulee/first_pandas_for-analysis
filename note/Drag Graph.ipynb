# %% [markdown]
# # 앤스콤 데이터 집합 불러온후 그래프 그리기

# %%
import seaborn as sns

anscombe =sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ## matplotlib 라이브러리로 그래프 그리기
# ###  plot (x ,y , f)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
dataset_1 = anscombe[anscombe['dataset'] == 'I']
plt.plot(dataset_1['x'], dataset_1['y'])
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # 엔스콤 데이터 집합 모두 사용해 그래프 만들기

# %% [markdown]
# ###  matplotlib 라이브러리로 그래프 그리기
# #### 1 전체 그래프가 위치할 기본 틀을 만든다
# #### 2 그래프를 그려 넣을 그래프 격자를 만듭니다.
# #### 3 그런 다음 격자에 그래프를 하나씩 추가 한다. 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽 방향이다
# #### 만약 격자의 첫 번쨰 행이 꽉 차면 두 번쨰 행에 그래프를 그려 넣습니다

# %%
# 앤스콤 데이터 프레임의 dataset 열값 저장
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# 그래프 격자가 위치할 기본틀 생성
fig =plt.figure()
# add_supplot 을 사용해 그래프 격자를 그림
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# plot메서드에 데이터를 전달하여 그래프를 그림
axes1.plot(dataset_1['x'], dataset_1['y'],'o')
axes2.plot(dataset_2['x'], dataset_2['y'],'o')
axes3.plot(dataset_3['x'], dataset_3['y'],'o')
axes4.plot(dataset_4['x'], dataset_4['y'],'o')

#각각의 그래프를 쉽게 구분할 수 있도록 격자에 제목 추가
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

# 기본 fig 에 제목을 추가  
fig.suptitle("anscombe Data")

# 각 그래프의 레이아웃을 조절하기
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # matplotlib 자유자재로 사용하기
# ### 추가로 고급 그래프 라이브러리인 seaborn  도 알아보자!

# %%
tips =sns.load_dataset('tips')
tips.head(), type(tips)
# Out:
# (   total_bill   tip     sex smoker  day    time  size
#  0       16.99  1.01  Female     No  Sun  Dinner     2
#  1       10.34  1.66    Male     No  Sun  Dinner     3
#  2       21.01  3.50    Male     No  Sun  Dinner     3
#  3       23.68  3.31    Male     No  Sun  Dinner     2
#  4       24.59  3.61  Female     No  Sun  Dinner     4,
#  pandas.core.frame.DataFrame)

# %% [markdown]
# ### 히스토그램은 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도로 자주 사용하는 그래프
# 변수를 하나만 사용해서 그린 그래프를 **일변량 그래프**라고 한다

# %%
#1 기본틀 만들기
fig = plt.figure()
#2 기본틀을 마련했으면  그래프 격자를 구성하기
axes1 = fig.add_subplot(1, 1, 1)
#3 hist 메소드에 total_bill 전달해서 히스토그램 만들기
# x 축의 간격은 bins 인자값으로 조정 
axes1.hist(tips['total_bill'], bins =10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ## 산점도 그래프 그리기
# ### 산점도 그래프는 변수 2개를 사용해서 만드는 그래프이며 변수 2개를 사용하기 떄문에 통계 용어로 '이변량 그래프'라고 부릅니다.

# %% [markdown]
# ### 기본 틀과 그래프 격자를 만들고 scatter 메소드에 total_bill, tips 열을 전달하면 된다

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## 박스 그래프 그리기 (이상치 확일할 떄 많이 쓰임)
# ### 박스 그래프는 이산형 변수와 연속형 변수를 함께 사용하는 그래프
# #### 이산형 변수(범주형 변수) = Female, Male과 같이 명확이 구분되는 값
# ### 연속형 변수란 tip과 같이 명확하게 셀 수 없는 범위의 값을 의미

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
               tips[tips['sex'] == 'Male']['tip']],
               labels = ['Female', 'Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title("Boxplot of Tip os Sex")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, 'Boxplot of Tip os Sex')

# %% [markdown]
# ## 다변량 그래프 그리기
# #### 2개의 변수를 사용한 그래프 ==  이변량 그래프
# #### 3개이상 변수를 사용한 그래프 == 다변량 그래프
#
# ### 다변량 그래프가 필요한 이유
# #### 위에서는 지불금액과 팁만을 이용하여 산점도 그래프를 나타냄 여기에 성별을 추가하여 삼전도 그래프를 표현하려면 어떻게 해야할까? ---> 점에 색상을 추가

# %% [markdown]
# ##### 다변량 데이터로 다변량 그래프 그리기  -- 산점도 그래프

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###  성별을 0 과 1로 범주형 변수로 변환한다

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1
tips['sex_color'] = tips['sex'].apply(recode_sex)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size'] * 50,
    c = tips['sex_color'],
    alpha = 0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Tip')
