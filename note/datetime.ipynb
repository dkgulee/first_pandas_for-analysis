# %% [markdown]
# # 시계열 데이터
# ### 시계열 데이터는 데이터 분석 분야에서 중요하게 다루는 데이터 중 하나다. 우리가 지금까지 다룬 날씨 관측 데이터, 에볼라 전염병으로 인한 사망자 수 관측 데이터, 빌보드 차트 데이터에는 모두 시계열 데이터가 포함되어 있다. 즉 일정 시간 간격으로 어떤 값을 기록한 데이터에서는 시계열 데이터가 매우 중요하다! 그렇기 떄문에 시계열 데이터를 자유자재로 다룰 줄 알아야 한다

# %% [markdown]
# # datetime 오브젝트
# ### datetime 라이브러리는 날짜와 시간을 처리하는 등 다양한 기능을 제공하는 파이선 라이브러리다. <br>날자를 처리하는 date 시간처리 time 날짜시간 모두 datetime

# %%
from datetime import datetime

# %%
now1 = datetime.now()
print(now1)
# Out:
# 2020-01-17 09:00:29.328634

# %%
now2 =datetime.today()
print(now2)
print(type(now2))
# Out:
# 2020-01-17 09:00:29.333621
# <class 'datetime.datetime'>

# %% [markdown]
# ## datetime()에 인자값을 넘겨  datetime 오브잭트가 생김

# %%
t1 = datetime.now()
t2 = datetime(1970, 1, 1)
t3 = datetime(1970, 12, 12, 13, 24, 34)
print(t1)
print(t2)
print(t3)
# Out:
# 2020-01-17 09:00:29.339605
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %% [markdown]
# ## datetime 오브젝틑 사용하는 이유 중 하나는 시간 계산을 할 수 있다!

# %%
diff1 = t1 - t2
print(diff1)
dfii2 = t2 - t1
print(dfii2)
# Out:
# 18278 days, 9:00:29.339605
# -18279 days, 14:59:30.660395

# %% [markdown]
# ## datetime 오브젝트로 변환하기 -to_datetime method

# %%
import pandas as pd
import os

ebola = pd.read_csv('../data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# date_dt                122 non-null datetime64[ns]
# ...

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15', '02/01/15', '03/01/15']})
print(test_df1)
print(type(test_df1))
test_df1['date_dt1'] = pd.to_datetime(test_df1['order_day'], format='%d/%m/%y')
test_df1['date_dt2'] = pd.to_datetime(test_df1['order_day'], format='%m/%d/%y')
test_df1['date_dt3'] = pd.to_datetime(test_df1['order_day'], format='%y/%m/%d')
print(test_df1)
# Out:
#   order_day
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15
# <class 'pandas.core.frame.DataFrame'>
#   order_day   date_dt1   date_dt2   date_dt3
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %% [markdown]
# ## datetime 오브젝트로 변환하기 - read_csv 메소드

# %%
ebola1 = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])
print(ebola1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null datetime64[ns]
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# ...

# %%
date_series = pd.Series(['2018-05-16', '2018-05-17', '2018-05-18'])
d1 = pd.to_datetime(date_series)
print(d1)
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[ns]

# %%
print(d1[0].year)
print(d1[0].month)
print(d1[2].day)
# Out:
# 2018
# 5
# 18

# %% [markdown]
# # dt 접근자 사용하기
#
# ### 문자열을 처리하려면 str 접근자를 사용한 다음 문자열 속성이나 메서드를 사용해야 했다.<br> datetime 오브젝트도 마찬가지로 dt 접근자를 사용하면 datetime 속성이나 메서드를 사용하여 시계열 데이터를 처리할 수 있다!

# %%
ebola = pd.read_csv('../data/country_timeseries.csv')
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola['date_dt'] =pd.to_datetime(ebola['Date'])
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola[['Date', 'date_dt']].head()
# Out:
#          Date    date_dt
# 0    1/5/2015 2015-01-05
# 1    1/4/2015 2015-01-04
# 2    1/3/2015 2015-01-03
# 3    1/2/2015 2015-01-02
# 4  12/31/2014 2014-12-31

# %% [markdown]
# ## dt 접근자를 사용하지 않고 인덱스가 3인 데이터 년월 일 데이터 추출

# %%
print(ebola['date_dt'][3].year)
print(ebola['date_dt'][3].month)
print(ebola['date_dt'][3].day)
# Out:
# 2015
# 1
# 2

# %%
ebola['year'] = ebola['date_dt'].dt.year
ebola[['Date', 'date_dt', 'year']]
# Out:
#            Date    date_dt  year
# 0      1/5/2015 2015-01-05  2015
# 1      1/4/2015 2015-01-04  2015
# 2      1/3/2015 2015-01-03  2015
# 3      1/2/2015 2015-01-02  2015
# 4    12/31/2014 2014-12-31  2014
# ..          ...        ...   ...
# 117   3/27/2014 2014-03-27  2014
# 118   3/26/2014 2014-03-26  2014
# 119   3/25/2014 2014-03-25  2014
# 120   3/24/2014 2014-03-24  2014
# 121   3/22/2014 2014-03-22  2014
#
# [122 rows x 3 columns]

# %%
ebola['month'] = ebola['date_dt'].dt.month
ebola[['Date', 'date_dt', 'year', 'month']]
ebola['day'] = ebola['date_dt'].dt.day
ebola[['Date', 'date_dt', 'year', 'month', 'day']]
# Out:
#            Date    date_dt  year  month  day
# 0      1/5/2015 2015-01-05  2015      1    5
# 1      1/4/2015 2015-01-04  2015      1    4
# 2      1/3/2015 2015-01-03  2015      1    3
# 3      1/2/2015 2015-01-02  2015      1    2
# 4    12/31/2014 2014-12-31  2014     12   31
# ..          ...        ...   ...    ...  ...
# 117   3/27/2014 2014-03-27  2014      3   27
# 118   3/26/2014 2014-03-26  2014      3   26
# 119   3/25/2014 2014-03-25  2014      3   25
# 120   3/24/2014 2014-03-24  2014      3   24
# 121   3/22/2014 2014-03-22  2014      3   22
#
# [122 rows x 5 columns]

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# date_dt                122 non-null datetime64[ns]
# ...

# %% [markdown]
# # 사례별 시계열 데이터 계산하기

# %%
print(ebola.iloc[-5:, :5])
print(ebola['date_dt'].min())
print(type(ebola['date_dt'].min()))
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN
# 2014-03-22 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ## 에볼라 진행 전동 알아보기 발생 시간 - 발생년도 최소값

# %%
ebola['outbreak_day'] = ebola['date_dt'] - ebola['date_dt'].min()

# %%
print(ebola[['Date', 'Day', 'outbreak_day']].head())
# Out:
#          Date  Day outbreak_day
# 0    1/5/2015  289     289 days
# 1    1/4/2015  288     288 days
# 2    1/3/2015  287     287 days
# 3    1/2/2015  286     286 days
# 4  12/31/2014  284     284 days

# %% [markdown]
# ## 파산한 은행의 개수 계산하기

# %%
banks = pd.read_csv('../data/banklist.csv')
banks
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
banks_no_dates = pd.read_csv('../data/banklist.csv')
print(banks_no_dates.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
# Bank Name                555 non-null object
# City                     555 non-null object
# ST                       555 non-null object
# CERT                     555 non-null int64
# Acquiring Institution    555 non-null object
# Closing Date             555 non-null object
# Updated Date             555 non-null object
# dtypes: int64(1), object(6)
# memory usage: 30.5+ KB
# None

# %%
banks = pd.read_csv('../data/banklist.csv', parse_dates=[5, 6])
banks.head(10)
# Out:
#                                            Bank Name                City  ST  \
# 0                Washington Federal Bank for Savings             Chicago  IL
# 1    The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 2                                Fayette County Bank          Saint Elmo  IL
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 4                                     First NBC Bank         New Orleans  LA
# 5                                      Proficio Bank  Cottonwood Heights  UT
# 6                      Seaway Bank and Trust Company             Chicago  IL
# 7                             Harvest Community Bank          Pennsville  NJ
# 8                                        Allied Bank            Mulberry  AR
# 9                       The Woodbury Banking Company            Woodbury  GA
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
banks['closing_quarter'], banks['closing_year'] = (banks['Closing Date'].dt.quarter, banks['Closing Date'].dt.year)

# %%
banks.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date  \
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05
#
#    closing_quarter  closing_year
# 0                4          2017
# 1                4          2017
# ...

# %% [markdown]
# ##  연도별로 파산한 은행이 얼마나 되지?

# %%
closing_year = banks.groupby(['closing_year']).size()
closing_year
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %% [markdown]
# # 각 연도별, 분기별로 파산한 은행의 개수도 알아봄

# %%
closing_year_q = banks.groupby(['closing_year', 'closing_quarter']).size()
closing_year_q
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()

ax = closing_year.plot()
plt.show()

fig ,ax = plt.subplots()
ax =closing_year_q.plot()
plt.show()

# %% [markdown]
# # 테슬라 주식 데이터로 시간 계산하기
# ### 이번에는 pandas_datareader 라이브러리를 이용하여 주식 데이터를 불러온다.<br> 명령 프롬프트에서 라이브러리를 설치
# ## https://www.quandl.com/ 들어가서 가입후 key에 값을 입력

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as pdr

# %% [markdown]
# # tesla에는 데이터프레임이 저장됨

# %%
tesla = pdr.get_data_quandl('TSLA', api_key= 'Kiq_w-dS9RzSyu7pHR3G')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-52-359f128ce721> in <module>
# ----> 1 tesla = pdr.get_data_quandl('TSLA', api_key= 'Kiq_w-dS9RzSyu7pHR3G')
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_quandl(*args, **kwargs)
#     100
#     101 def get_data_quandl(*args, **kwargs):
# --> 102     return QuandlReader(*args, **kwargs).read()
#     103
#     104
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\quandl.py in read(self)
#     135     def read(self):
#     136         """Read data"""
# --> 137         df = super(QuandlReader, self).read()
#     138         df.rename(
#     139             columns=lambda n: n.replace(" ", "")
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     249         # If a single symbol, (e.g., 'GOOG')
#     250         if isinstance(self.symbols, (string_types, int)):
# ...

# %%
tesla = pd.read_csv('../data/tesla_stock_quandl.csv')
tesla.head()

# %%
print(tesla.info())

# %%
tesla = pd.read_csv('../data/tesla_stock_quandl.csv', parse_dates=[0])
print(tesla.info())

# %%
print(tesla.loc[(tesla.Date.dt.year == 2010) & (tesla.Date.dt.month == 6)])

# %% [markdown]
# ## datetime 오브젝트와 인덱스 - DatetimeIndex
# #### 지금까지의 실습은 대부분 데이터프레이;ㅁ의 행 번호를 인덱스로 사용햇지만 datetime 오브젝트를 데이터프레임의 인덱스로 설정하면 원하는 시간의 데이터를 바로 추출할 수 있다!

# %% [markdown]
# ## 테슬라의 Date 열을 tesla 데이터프레임의 인덱스로 지정

# %%
tesla.index = tesla['Date']
print(tesla.index)

# %%
tesla['2015'].iloc[:6,:5]

# %%
tesla['2010-06'].iloc[:, :5]

# %% [markdown]
# # 시간 간격과 인덱스 - Timedeltaindex
# ### 예를들어 주식 데이터에서 최초 5일간 수집된 데이터만 살펴보고 싶다면 어떻게 할까요?
# ### 이런 경우에는 시간 간격을 인덱스로 지정해서 데이터를 추출하면 됩니다. 이번에는 datetime 오브젝트를 인덱스로 지정하는게 아니라 시간 간격을 인덱스로 지정하여 진행해보겠습니다.

# %% [markdown]
# ## Date 열에서 Date 열의 최솟값을 뺴면 데이터를 수집한 이후에 시간이 얼마나 흘렀는지 알 수 있다

# %%
tesla['ref_date'] = tesla['Date'] - tesla['Date'].min()
print(tesla.head())

# %%
tesla.index = tesla['ref_date']
tesla.iloc[:7, :5]

# %% [markdown]
# # 데이터를 수집한 이후 최초 5일의 데이터를 추출한 것

# %%
tesla['5 days':].iloc[:5, :5]

# %% [markdown]
# # 시간 범위와 인덱스
#
# ## 만약 특정일에 누락된 데이터도 포함시켜 데이터를 살펴보려면 어떻게 해야하나요? 이런 경우에는 임의로 시간 범위를 생성하여 인덱스로 지정해야 한다

# %%
ebola = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
ebola.iloc[:6,:5]

# %%
ebola.iloc[-5:,:5]

# %%
head_range = pd.date_range(start='2014-12-31', end='2015-01-05')
print(head_range)

# %%
ebloa_5 = ebola.head()
ebloa_5.index = ebloa_5['Date']
ebloa_5.reindex(head_range)
ebloa_5.iloc[:5, :5]

# %% [markdown]
# # 시간 범위의 주기 설정하기
# ### 시간 범위를 인덱스로 지정하면 DatetimeIndex 자료형이 만들어 진다 그리고  DatetimeIndex에는 freq 속성이 있는데 freq 속성값을 지정하면 시간 간격을 조절하여   DatetimeIndex 를 만들 수 있다.

# %%
 DatetimeIndexfreq = pd.DataFrame({
     "시간주기": ['B','C','D','W','M','SM','BM','CBM','MS','SMS','BMS','CBMS','Q','BQ','QS','BQS','A','BA','AS','BAS','BH','H','T','S','L','U','N'],
     "설명" : ['평일만포함','사용자가 정의한 평일만 포함','달력 일자 단위', '주간 단위','월마지막 날만 포함','15일과 월 마지막 날만 포함',
             'M 주기의 값이 휴일이면 제외하고 평일만 포함', 'BM에 사용자 정의 평일을 적용', '월 시작일만 포함', '월 시작일과 15만 포함',
             'MS 주기의 값이 휴일이면 제외하고 평일만 포함', 'BMS에 사용자 정의 평일을 적용', '3,6,9,12월 분기 마지막날만 포함','3,6,9,12월 분기 마지막 날이 휴일이면 제외하고 평일만 포함'
            ,'3,6,9,12월 분기 시작일만 포함', '3,6,9,12월 분기 시작일이 휴일이면 제외하고 평일만 포함', '년의 마지막 날만 포함', '년의 마지막 날이 휴일이면 제외하고 평일만 포함', '년의 시작일만 포함', '년의 시작일이 휴일이면 제외하고 평일만 포함', '평일을 시간 단위로 포함(09:00 ~ 16:00)',
             '시간 단위로 포함(00:00 ~ 00:00)','분 단위 포함', '초 단위 포함', '밀리초 단위 포함', '마이크로초 단위 포함', '나노초 단위 포함']
 })

# %%
DatetimeIndexfreq
# Out:
#     시간주기                                    설명
# 0      B                                 평일만포함
# 1      C                       사용자가 정의한 평일만 포함
# 2      D                              달력 일자 단위
# 3      W                                 주간 단위
# 4      M                            월마지막 날만 포함
# 5     SM                      15일과 월 마지막 날만 포함
# 6     BM             M 주기의 값이 휴일이면 제외하고 평일만 포함
# 7    CBM                     BM에 사용자 정의 평일을 적용
# 8     MS                             월 시작일만 포함
# 9    SMS                         월 시작일과 15만 포함
# 10   BMS            MS 주기의 값이 휴일이면 제외하고 평일만 포함
# 11  CBMS                    BMS에 사용자 정의 평일을 적용
# 12     Q                 3,6,9,12월 분기 마지막날만 포함
# 13    BQ  3,6,9,12월 분기 마지막 날이 휴일이면 제외하고 평일만 포함
# 14    QS                  3,6,9,12월 분기 시작일만 포함
# 15   BQS    3,6,9,12월 분기 시작일이 휴일이면 제외하고 평일만 포함
# 16     A                          년의 마지막 날만 포함
# 17    BA            년의 마지막 날이 휴일이면 제외하고 평일만 포함
# 18    AS                            년의 시작일만 포함
# ...

# %% [markdown]
# ## 시간 범위 수정하고 데이터 밀어내기 -shift메서드
# #### 만약 나라별로 에볼라의 확산 속도를 비교하려면 발생하기 시작한 날짜를 옮기는 것이 좋다
# #### 에볼라의 확산속도 비교하기
# #### x축을 Date 열로 y축을 사망자 수로 지정하여 그림

# %%
import matplotlib.pyplot as plt
ebola = pd.read_csv('../data/country_timeseries.csv')
ebola.index = ebola['Date']

fig, ax =plt.subplots()
ax = ebola.iloc[0:, 1:].plot(ax=ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0.)

# %% [markdown]
# ### 위 과정의 그래프는 나라의 에볼라 발병일이 달라 그래프가 그려지기 시작한 지점도 다르다. 달리기 속도를 비교하려면 같은 출발선에서 출발하여 시간을 측정해야된다. 에볼라의 확산 속도도 같은 방법으로 측정 해야 합니다. 즉, 각 나라의 발병일을 가장 처음 에볼라가 발병한 Guinea와 동일한 위치로 옮겨야 나라별 에볼라의 확산 속도를 제대로 비교할 수 있다

# %%
ebola.head(10)
# Out:
#                   Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 1/5/2015      1/5/2015  289        2776.0            NaN            10030.0
# 1/4/2015      1/4/2015  288        2775.0            NaN             9780.0
# 1/3/2015      1/3/2015  287        2769.0         8166.0             9722.0
# 1/2/2015      1/2/2015  286           NaN         8157.0                NaN
# 12/31/2014  12/31/2014  284        2730.0         8115.0             9633.0
# 12/28/2014  12/28/2014  281        2706.0         8018.0             9446.0
# 12/27/2014  12/27/2014  280        2695.0            NaN             9409.0
# 12/24/2014  12/24/2014  277        2630.0         7977.0             9203.0
# 12/21/2014  12/21/2014  273        2597.0            NaN             9004.0
# 12/20/2014  12/20/2014  272        2571.0         7862.0             8939.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# ...

# %%
print(ebola.index.mean())
# Out:
# 2014-08-13 20:15:44.262295040

# %%
ebla_sub = ebola[['Day', 'Cases_Guinea', 'Cases_Liberia']]
ebla_sub.tail(10)
# Out:
#            Day  Cases_Guinea  Cases_Liberia
# Date
# 4/4/2014    13         143.0           18.0
# 4/1/2014    10         127.0            8.0
# 3/31/2014    9         122.0            8.0
# 3/29/2014    7         112.0            7.0
# 3/28/2014    6         112.0            3.0
# 3/27/2014    5         103.0            8.0
# 3/26/2014    4          86.0            NaN
# 3/25/2014    3          86.0            NaN
# 3/24/2014    2          86.0            NaN
# 3/22/2014    0          49.0            NaN

# %% [markdown]
# ## 그래프를 그리기 위한 데이터 프레임 준비하기
# #### Date 열의 자료형을 datetime 오브젝트로 변환하여 ebola 데이터프레임을 다시 생성

# %%
ebola = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])
print(ebola.head().iloc[:,:5])
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0

# %%
print(ebola.tail().iloc[:,:5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %% [markdown]
# ### 'Date' 열을 인덱스로 지정한 다음 ebola 데이터 프레임의 Date 열의 최댓값과 최솟값으로 시간 범위를 생성하여 new_idx에 저장한것

# %%
ebola.index = ebola['Date']
new_idx = pd.date_range(ebola.index.min(), ebola.index.max())
ebola.head()
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
#
# ...

# %%
new_idx
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', length=290, freq='D')

# %%
new_idx = reversed(new_idx)

# %%
ebola = ebola.reindex(new_idx)
print(ebola.head().iloc[:, :5])

print(ebola.tail().iloc[:, :5])
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2014-03-26 2014-03-26  4.0          86.0            NaN                NaN
# 2014-03-25 2014-03-25  3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24  2.0          86.0            NaN                NaN
# 2014-03-23        NaT  NaN           NaN            NaN                NaN
# 2014-03-22 2014-03-22  0.0          49.0            NaN                NaN

# %% [markdown]
# ## 각 나라의 에볼라 발병일 옮기기
# ### 다음은 last_valid_index, first_valid_index 메서그를 사용하여 각 나라의 에볼라 발병일을 구한것.
# ## last_valid_index = 가장 오래된 데이터를 가져옴
# ## first_valid_index = 가장 최근의 데이터를 가져옴

# %%
last_valid = ebola.apply(pd.Series.last_valid_index)
print(last_valid)

first_valid = ebola.apply(pd.Series.first_valid_index)
print(first_valid)
# Out:
# Date                  2014-03-22
# Day                   2014-03-22
# Cases_Guinea          2014-03-22
# Cases_Liberia         2014-03-27
# Cases_SierraLeone     2014-03-27
# Cases_Nigeria         2014-07-23
# Cases_Senegal         2014-08-31
# Cases_UnitedStates    2014-10-01
# Cases_Spain           2014-10-08
# Cases_Mali            2014-10-22
# Deaths_Guinea         2014-03-22
# Deaths_Liberia        2014-03-27
# Deaths_SierraLeone    2014-03-27
# Deaths_Nigeria        2014-07-23
# Deaths_Senegal        2014-09-07
# Deaths_UnitedStates   2014-10-01
# Deaths_Spain          2014-10-08
# Deaths_Mali           2014-10-22
# dtype: datetime64[ns]
# Date                  2015-01-05
# Day                   2015-01-05
# Cases_Guinea          2015-01-05
# Cases_Liberia         2015-01-03
# Cases_SierraLeone     2015-01-05
# Cases_Nigeria         2014-12-07
# Cases_Senegal         2014-12-07
# Cases_UnitedStates    2014-12-07
# Cases_Spain           2014-12-07
# ...

# %% [markdown]
# ### 각 나라의 에볼라 발병일을 동일한 출반선으로 옮기려면 에볼라가 가장 처음 발병한(earliest_date)에서 각 나라의 에볼라 발병일을 뺸 만큼(shift_values) 만 옮기면 된다.

# %%
earliest_date = ebola.index.min()
print(earliest_date)

shift_values = last_valid - earliest_date
print(shift_values)
# Out:
# 2014-03-22 00:00:00
# Date                    0 days
# Day                     0 days
# Cases_Guinea            0 days
# Cases_Liberia           5 days
# Cases_SierraLeone       5 days
# Cases_Nigeria         123 days
# Cases_Senegal         162 days
# Cases_UnitedStates    193 days
# Cases_Spain           200 days
# Cases_Mali            214 days
# Deaths_Guinea           0 days
# Deaths_Liberia          5 days
# Deaths_SierraLeone      5 days
# Deaths_Nigeria        123 days
# Deaths_Senegal        169 days
# Deaths_UnitedStates   193 days
# Deaths_Spain          200 days
# Deaths_Mali           214 days
# dtype: timedelta64[ns]

# %% [markdown]
# ### 이제 각 나라의 에볼라 발병일을 옮기면 된다 다음은 shift 메서드를 사용하여 모든 열의 값을 shift_values 값만큼 옮긴 것이다. shift 메서드는 인자값만큼 데이터를 밀어 내는 메서드입니다.

# %%
ebola_dict = {}
for idx, col in enumerate(ebola):
    d = shift_values[idx].days
    shifted = ebola[col].shift(d)
    ebola_dict[col] = shifted

# %%
ebola_shift = pd.DataFrame(ebola_dict)

# %%
ebola_shift.tail()
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-03-26 2014-03-26  4.0          86.0            8.0                2.0
# 2014-03-25 2014-03-25  3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24  2.0          86.0            7.0                NaN
# 2014-03-23        NaT  NaN           NaN            3.0                2.0
# 2014-03-22 2014-03-22  0.0          49.0            8.0                6.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2014-03-26            1.0            NaN                 1.0          1.0
# 2014-03-25            NaN            NaN                 NaN          NaN
# 2014-03-24            NaN            NaN                 NaN          NaN
# 2014-03-23            NaN            NaN                 NaN          NaN
# 2014-03-22            0.0            1.0                 1.0          1.0
#
# ...

# %% [markdown]
# ## 마지막으로 인덱스를 Day 열로 지정하고 그래프에 필요 없는 Date, Day 열은 삭제하면 그래프를 그리기 위한 데이터프레임이 완성된다.

# %%
ebola_shift.index = ebola_shift['Day']
ebola_shift = ebola_shift.drop(['Date', 'Day'], axis =1)
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 4.0          86.0            8.0                2.0            1.0
# 3.0          86.0            NaN                NaN            NaN
# 2.0          86.0            7.0                NaN            NaN
# NaN           NaN            3.0                2.0            NaN
# 0.0          49.0            8.0                6.0            0.0
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 4.0            NaN                 1.0          1.0         NaN
# 3.0            NaN                 NaN          NaN         NaN
# 2.0            NaN                 NaN          NaN         NaN
# NaN            NaN                 NaN          NaN         NaN
# 0.0            1.0                 1.0          1.0         1.0
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Day
# 4.0           62.0             4.0                 2.0             1.0
# ...

# %%
ebola_shift.tail()
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 4.0          86.0            8.0                2.0            1.0
# 3.0          86.0            NaN                NaN            NaN
# 2.0          86.0            7.0                NaN            NaN
# NaN           NaN            3.0                2.0            NaN
# 0.0          49.0            8.0                6.0            0.0
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 4.0            NaN                 1.0          1.0         NaN
# 3.0            NaN                 NaN          NaN         NaN
# 2.0            NaN                 NaN          NaN         NaN
# NaN            NaN                 NaN          NaN         NaN
# 0.0            1.0                 1.0          1.0         1.0
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Day
# 4.0           62.0             4.0                 2.0             1.0
# ...

# %%
fig, ax =plt.subplots()
ax = ebola_shift.iloc[:,:].plot(ax= ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0.)
plt.show()
